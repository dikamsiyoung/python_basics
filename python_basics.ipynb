# %% [markdown]
# # Python Basics
# This file presents the basic python syntax and uses cases learned from the Python Basics Coursera Course presented by the Univerisity of Michigan.

# %% [markdown]
# ## Week 1: Python Syntax and Variables

# %% [markdown]
# ## Week 2: Sequences and Iterations

# %% [markdown]
# ## Week 3: Boolean Expression and Conditional Execution

# %%
rainfall_mi = "1.65, 1.46, 2.05, 3.03, 3.35, 3.46, 2.83, 3.23, 3.5, 2.52, 2.8, 1.85"
rainfall_list = rainfall_mi.split(',')

num_rainy_months = 0
for measurement in rainfall_list:
    measurement_num = float(measurement)
    if measurement_num > 3.0:
        num_rainy_months += 1
        
print('Number of months with greater than 3.0: ', num_rainy_months)
# Out:
# Number of months with greater than 3.0:  5

# %%
sentence = "students flock to the arb for a variety of outdoor activities such as jogging and picnicking"

sentence_list = sentence.split(' ')
same_letter_count = 0
for word in sentence_list:
    if word[0] == word[-1]:
        same_letter_count += 1

print('Words in sentence with the same letters: ', same_letter_count)
# Out:
# Words in sentence with the same letters:  2

# %%
items = ["whirring", "wow!", "calendar", "wry", "glass", "", "llama","tumultuous","owing"]

acc_num = 0
for word in items:
    if 'w' in word:
        acc_num += 1

print("Words in item with 'W': ", acc_num)
# Out:
# Words in item with 'W':  4

# %%
sentence = "python is a high level general purpose programming language that can be applied to many different classes of problems."

sentence_list = sentence.split(' ')
num_a_or_e = 0
for word in sentence_list:
    if 'a' in word or 'e' in word:
        num_a_or_e += 1

print("Words in sentence with 'a' or 'e': ", num_a_or_e)
# Out:
# Words in sentence with 'a' or 'e':  14

# %%
s = "singing in the rain and playing in the rain are two entirely different situations but both can be fun"
vowels = ['a','e','i','o','u']

# Write your code here.
num_vowels = 0
for char in s:
    for vowel in vowels:
        if vowel == char:
            num_vowels += 1

print("Number of vowels in s: ", num_vowels)
# Out:
# Number of vowels in s:  32

# %% [markdown]
# ## Week 4: Sequence Mutation

# %%
## Insert to 3rd position 'Horseback Riding'
sports = ['cricket', 'football', 'volleyball', 'baseball', 'softball', 'track and field', 'curling', 'ping pong', 'hockey']

sports.insert(2, 'horseback riding')
print('Insert operation: ', sports)
# Out:
# Insert operation:  ['cricket', 'football', 'horseback riding', 'volleyball', 'baseball', 'softball', 'track and field', 'curling', 'ping pong', 'hockey']

# %%
## Remove 'London' from the list
trav_dest = ['Beirut', 'Milan', 'Pittsburgh', 'Buenos Aires', 'Nairobi', 'Kathmandu', 'Osaka', 'London', 'Melbourne']

trav_dest.remove('London')
print('Remove Operation')
# Out:
# Remove Operation

# %%
## Add 'Guadalajara' to the end of the list
trav_dest = ['Beirut', 'Milan', 'Pittsburgh', 'Buenos Aires', 'Nairobi', 'Kathmandu', 'Osaka', 'Melbourne']

trav_dest.append('Guadalajara')
print('Append operation')
# Out:
# Append operation

# %%
## Below are a set of scores that students have received in the past semester. Write code to determine how many are 90 or above and assign that result to the value a_scores.

scores = "67 80 90 78 93 20 79 89 96 97 92 88 79 68 58 90 98 100 79 74 83 88 80 86 85 70 90 100"

scores_lst = scores.split(" ")
a_scores = 0
for score in scores_lst:
    if int(score) >= 90:
        a_scores += 1

print('Number of scores greater than 90: ', a_scores)
# Out:
# Number of scores greater than 90:  10

# %%
## Write code that uses the string stored in org and creates an acronym which is assigned to the variable acro. Only the first letter of each word should be used, each letter in the acronym should be a capital letter, and there should be nothing to separate the letters of the acronym. Words that should not be included in the acronym are stored in the list stopwords. For example, if org was assigned the string “hello to world” then the resulting acronym should be “HW”.

stopwords = ['to', 'a', 'for', 'by', 'an', 'am', 'the', 'so', 'it', 'and', "The"]
org = "The organization for health, safety, and education"

def checkString(string):
    for wrd in stopwords:
        if string == wrd:
            return True
    return False

acro = ''
org_lst = org.split(" ")
for wrd in org_lst:
    if checkString(wrd):
        pass
    else:
        acro = acro + wrd[0].upper()

print("Acronym is: ", acro)
# Out:
# Acronym is:  OHSE

# %%
## Write code that uses the string stored in sent and creates an acronym which is assigned to the variable acro. The first two letters of each word should be used, each letter in the acronym should be a capital letter, and each element of the acronym should be separated by a “. ” (dot and space). Words that should not be included in the acronym are stored in the list stopwords. For example, if sent was assigned the string “height and ewok wonder” then the resulting acronym should be “HE. EW. WO”.

stopwords = ['to', 'a', 'for', 'by', 'an', 'am', 'the', 'so', 'it', 'and', 'The']
sent = "The water earth and air are vital"

def checkString(string):
    for wrd in stopwords:
        if string == wrd:
            return True
    return False


sent_lst = sent.split(" ")
acro_so_far = []
for wrd in sent_lst:
    if checkString(wrd):
        pass
    else:
        acro_so_far.append(wrd[0:2].upper())

acro = ". ".join(acro_so_far)
print('Acronyms: ', acro)
# Out:
# Acronyms:  WA. EA. AI. AR. VI

# %%
## A palindrome is a phrase that, if reversed, would read the exact same. Write code that checks if p_phrase is a palindrome by reversing it and then checking if the reversed version is equal to the original. Assign the reversed version of p_phrase to the variable r_phrase so that we can check your work.

p_phrase = "was it a car or a cat I saw"

p_phrase_lst = p_phrase.split(" ")
p_phrase_lst.reverse()
r_phrase = ""
accum = []
for wrd in p_phrase_lst:
    accum.append(wrd[::-1])

r_phrase = " ".join(accum)
print('"{}"'.format(p_phrase), 'is not the same if reversed to give ', '"{}"'.format(r_phrase))
# Out:
# "was it a car or a cat I saw" is not the same if reversed to give  "was I tac a ro rac a ti saw"

# %%
## Provided is a list of data about a store’s inventory where each item in the list represents the name of an item, how much is in stock, and how much it costs. Print out each item in the list with the same formatting, using the .format method (not string concatenation). For example, the first print statment should read The store has 12 shoes, each for 29.99 USD.

inventory = ["shoes, 12, 29.99", "shirts, 20, 9.99", "sweatpants, 25, 15.00", "scarves, 13, 7.75"]

for item in inventory:
    field_lst = item. split(", ")
    print('The store has {} {}, each for {:.2f} USD.'.format(field_lst[1], field_lst[0], float(field_lst[2])))
# Out:
# The store has 12 shoes, each for 29.99 USD.
# The store has 20 shirts, each for 9.99 USD.
# The store has 25 sweatpants, each for 15.00 USD.
# The store has 13 scarves, each for 7.75 USD.
